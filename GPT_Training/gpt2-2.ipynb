# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/notebook9c426c2851/__results__.html
# /kaggle/input/notebook9c426c2851/__notebook__.ipynb
# /kaggle/input/notebook9c426c2851/__output__.json
# /kaggle/input/notebook9c426c2851/custom.css
# /kaggle/input/notebook9c426c2851/fine-tuned-gpt2/config.json
# /kaggle/input/notebook9c426c2851/fine-tuned-gpt2/merges.txt
# /kaggle/input/notebook9c426c2851/fine-tuned-gpt2/vocab.json
# /kaggle/input/notebook9c426c2851/fine-tuned-gpt2/tokenizer_config.json
# /kaggle/input/notebook9c426c2851/fine-tuned-gpt2/model.safetensors
# /kaggle/input/notebook9c426c2851/fine-tuned-gpt2/special_tokens_map.json
# /kaggle/input/notebook9c426c2851/fine-tuned-gpt2/generation_config.json
# /kaggle/input/notebook9c426c2851/results/runs/Sep13_15-46-01_db672bf623d8/events.out.tfevents.1726242363.db672bf623d8.22.0
# /kaggle/input/notebook9c426c2851/results/checkpoint-85170/config.json
# /kaggle/input/notebook9c426c2851/results/checkpoint-85170/trainer_state.json
# /kaggle/input/notebook9c426c2851/results/checkpoint-85170/training_args.bin
# /kaggle/input/notebook9c426c2851/results/checkpoint-85170/scheduler.pt
# /kaggle/input/notebook9c426c2851/results/checkpoint-85170/model.safetensors
# /kaggle/input/notebook9c426c2851/results/checkpoint-85170/optimizer.pt
# /kaggle/input/notebook9c426c2851/results/checkpoint-85170/rng_state.pth
# /kaggle/input/notebook9c426c2851/results/checkpoint-85170/generation_config.json
# /kaggle/input/notebook9c426c2851/results/checkpoint-85000/config.json
# /kaggle/input/notebook9c426c2851/results/checkpoint-85000/trainer_state.json
# /kaggle/input/notebook9c426c2851/results/checkpoint-85000/training_args.bin
# /kaggle/input/notebook9c426c2851/results/checkpoint-85000/scheduler.pt
# /kaggle/input/notebook9c426c2851/results/checkpoint-85000/model.safetensors
# /kaggle/input/notebook9c426c2851/results/checkpoint-85000/optimizer.pt
# /kaggle/input/notebook9c426c2851/results/checkpoint-85000/rng_state.pth
# /kaggle/input/notebook9c426c2851/results/checkpoint-85000/generation_config.json
# /kaggle/input/notebook9c426c2851/wandb/run-20240913_154603-k3k5ph8l/run-k3k5ph8l.wandb
# /kaggle/input/notebook9c426c2851/wandb/run-20240913_154603-k3k5ph8l/logs/debug.log
# /kaggle/input/notebook9c426c2851/wandb/run-20240913_154603-k3k5ph8l/logs/debug-internal.log
# /kaggle/input/notebook9c426c2851/wandb/run-20240913_154603-k3k5ph8l/files/wandb-summary.json
# /kaggle/input/notebook9c426c2851/wandb/run-20240913_154603-k3k5ph8l/files/conda-environment.yaml
# /kaggle/input/notebook9c426c2851/wandb/run-20240913_154603-k3k5ph8l/files/config.yaml
# /kaggle/input/notebook9c426c2851/wandb/run-20240913_154603-k3k5ph8l/files/output.log
# /kaggle/input/notebook9c426c2851/wandb/run-20240913_154603-k3k5ph8l/files/requirements.txt
# /kaggle/input/notebook9c426c2851/wandb/run-20240913_154603-k3k5ph8l/files/wandb-metadata.json
# /kaggle/input/food-com-recipes-and-user-interactions/RAW_interactions.csv
# /kaggle/input/food-com-recipes-and-user-interactions/ingr_map.pkl
# /kaggle/input/food-com-recipes-and-user-interactions/PP_recipes.csv
# /kaggle/input/food-com-recipes-and-user-interactions/RAW_recipes.csv
# /kaggle/input/food-com-recipes-and-user-interactions/interactions_train.csv
# /kaggle/input/food-com-recipes-and-user-interactions/interactions_test.csv
# /kaggle/input/food-com-recipes-and-user-interactions/PP_users.csv
# /kaggle/input/food-com-recipes-and-user-interactions/interactions_validation.csv

# %%
# Read data
import pickle

ingr_map = pd.read_pickle("/kaggle/input/food-com-recipes-and-user-interactions/ingr_map.pkl")
input_path = "/kaggle/input/food-com-recipes-and-user-interactions/"
df_recipes = pd.read_csv(input_path + "RAW_recipes.csv")

print(df_recipes.shape)
# Out:
# (231637, 12)

# %%
df_recipes.head()
# Out:
#                                          name      id  minutes  \
# 0  arriba   baked winter squash mexican style  137739       55
# 1            a bit different  breakfast pizza   31490       30
# 2                   all in the kitchen  chili  112140      130
# 3                          alouette  potatoes   59389       45
# 4          amish  tomato ketchup  for canning   44061      190
#
#    contributor_id   submitted  \
# 0           47892  2005-09-16
# 1           26278  2002-06-17
# 2          196586  2005-02-25
# 3           68585  2003-04-14
# 4           41706  2002-10-25
#
#                                                 tags  \
# 0  ['60-minutes-or-less', 'time-to-make', 'course...
# 1  ['30-minutes-or-less', 'time-to-make', 'course...
# 2  ['time-to-make', 'course', 'preparation', 'mai...
# 3  ['60-minutes-or-less', 'time-to-make', 'course...
# 4  ['weeknight', 'time-to-make', 'course', 'main-...
#
#                                     nutrition  n_steps  \
# 0       [51.5, 0.0, 13.0, 0.0, 2.0, 0.0, 4.0]       11
# 1   [173.4, 18.0, 0.0, 17.0, 22.0, 35.0, 1.0]        9
# 2  [269.8, 22.0, 32.0, 48.0, 39.0, 27.0, 5.0]        6
# 3   [368.1, 17.0, 10.0, 2.0, 14.0, 8.0, 20.0]       11
# 4   [352.9, 1.0, 337.0, 23.0, 3.0, 0.0, 28.0]        5
#
#                                                steps  \
# 0  ['make a choice and proceed with recipe', 'dep...
# 1  ['preheat oven to 425 degrees f', 'press dough...
# 2  ['brown ground beef in large pot', 'add choppe...
# 3  ['place potatoes in a large pot of lightly sal...
# 4  ['mix all ingredients& boil for 2 1 / 2 hours ...
#
#                                          description  \
# 0  autumn is my favorite time of year to cook! th...
# 1  this recipe calls for the crust to be prebaked...
# 2  this modified version of 'mom's' chili was a h...
# 3  this is a super easy, great tasting, make ahea...
# 4  my dh's amish mother raised him on this recipe...
#
#                                          ingredients  n_ingredients
# 0  ['winter squash', 'mexican seasoning', 'mixed ...              7
# 1  ['prepared pizza crust', 'sausage patty', 'egg...              6
# 2  ['ground beef', 'yellow onions', 'diced tomato...             13
# 3  ['spreadable cheese with garlic and herbs', 'n...             11
# 4  ['tomato juice', 'apple cider vinegar', 'sugar...              8

# %%
import ast

replacement_dict = pd.Series(ingr_map['replaced'].values, index=ingr_map['raw_ingr']).to_dict()

# Function to convert and replace ingredients
def convert_and_replace(ingredient_str, replacement_dict):
    try:
        # Convert string representation of list to actual list
        ingredient_list = ast.literal_eval(ingredient_str)
        # Replace ingredients
        replaced_list = [replacement_dict.get(ingredient, ingredient) for ingredient in ingredient_list]
        return replaced_list
    except (ValueError, SyntaxError):
        # Handle cases where conversion fails
        return []

# Apply replacement to the ingredients column
df_recipes['ingredients'] = df_recipes['ingredients'].apply(lambda x: convert_and_replace(x, replacement_dict))

# %%
print(df_recipes.shape)
df_recipes.head()
# Out:
# (231637, 12)
#                                          name      id  minutes  \
# 0  arriba   baked winter squash mexican style  137739       55
# 1            a bit different  breakfast pizza   31490       30
# 2                   all in the kitchen  chili  112140      130
# 3                          alouette  potatoes   59389       45
# 4          amish  tomato ketchup  for canning   44061      190
#
#    contributor_id   submitted  \
# 0           47892  2005-09-16
# 1           26278  2002-06-17
# 2          196586  2005-02-25
# 3           68585  2003-04-14
# 4           41706  2002-10-25
#
#                                                 tags  \
# 0  ['60-minutes-or-less', 'time-to-make', 'course...
# 1  ['30-minutes-or-less', 'time-to-make', 'course...
# 2  ['time-to-make', 'course', 'preparation', 'mai...
# 3  ['60-minutes-or-less', 'time-to-make', 'course...
# 4  ['weeknight', 'time-to-make', 'course', 'main-...
#
#                                     nutrition  n_steps  \
# 0       [51.5, 0.0, 13.0, 0.0, 2.0, 0.0, 4.0]       11
# 1   [173.4, 18.0, 0.0, 17.0, 22.0, 35.0, 1.0]        9
# 2  [269.8, 22.0, 32.0, 48.0, 39.0, 27.0, 5.0]        6
# 3   [368.1, 17.0, 10.0, 2.0, 14.0, 8.0, 20.0]       11
# 4   [352.9, 1.0, 337.0, 23.0, 3.0, 0.0, 28.0]        5
#
#                                                steps  \
# 0  ['make a choice and proceed with recipe', 'dep...
# 1  ['preheat oven to 425 degrees f', 'press dough...
# 2  ['brown ground beef in large pot', 'add choppe...
# 3  ['place potatoes in a large pot of lightly sal...
# 4  ['mix all ingredients& boil for 2 1 / 2 hours ...
#
#                                          description  \
# 0  autumn is my favorite time of year to cook! th...
# 1  this recipe calls for the crust to be prebaked...
# 2  this modified version of 'mom's' chili was a h...
# 3  this is a super easy, great tasting, make ahea...
# 4  my dh's amish mother raised him on this recipe...
#
#                                          ingredients  n_ingredients
# 0  [winter squash, mexican seasoning, mixed spice...              7
# 1  [pizza crust, sausage, egg, milk, salt and pep...              6
# 2  [ground beef, yellow onion, diced tomato, toma...             13
# 3  [cheese, new potato, shallot, parsley, tarrago...             11
# 4  [tomato juice, apple cider vinegar, sugar, sal...              8

# %%
df_recipes = df_recipes.iloc[:57909]
print(df_recipes.shape)
# Out:
# (57909, 12)

# %%
# Combine the relevant columns into a new dataframe
df_simplified = df_recipes[['minutes', 'ingredients', 'steps']].copy()

# Format the ingredients as a comma-separated string for better readability
df_simplified['ingredients'] = df_simplified['ingredients'].apply(lambda x: ', '.join(x))

# Combine all columns into a single text block format for the transformer model
def format_recipe_simple(row):
    return (
        f"Cooking Time: {row['minutes']} minutes "
        f"Ingredients: {row['ingredients']} "
        f"Steps: {row['steps']} "
    )

df_simplified['formatted_recipe'] = df_simplified.apply(format_recipe_simple, axis=1)

df_simplified.head()
# Out:
#    minutes                                        ingredients  \
# 0       55  winter squash, mexican seasoning, mixed spice,...
# 1       30  pizza crust, sausage, egg, milk, salt and pepp...
# 2      130  ground beef, yellow onion, diced tomato, tomat...
# 3       45  cheese, new potato, shallot, parsley, tarragon...
# 4      190  tomato juice, apple cider vinegar, sugar, salt...
#
#                                                steps  \
# 0  ['make a choice and proceed with recipe', 'dep...
# 1  ['preheat oven to 425 degrees f', 'press dough...
# 2  ['brown ground beef in large pot', 'add choppe...
# 3  ['place potatoes in a large pot of lightly sal...
# 4  ['mix all ingredients& boil for 2 1 / 2 hours ...
#
#                                     formatted_recipe
# 0  Cooking Time: 55 minutes Ingredients: winter s...
# 1  Cooking Time: 30 minutes Ingredients: pizza cr...
# 2  Cooking Time: 130 minutes Ingredients: ground ...
# 3  Cooking Time: 45 minutes Ingredients: cheese, ...
# 4  Cooking Time: 190 minutes Ingredients: tomato ...

# %%
recipes = df_simplified['formatted_recipe'].tolist()

from transformers import GPT2Tokenizer, GPT2LMHeadModel, Trainer, TrainingArguments
import torch

# Load the pre-trained GPT-2 model and tokenizer
# model_name = "gpt2"
tokenizer = GPT2Tokenizer.from_pretrained('/kaggle/input/notebook9c426c2851/fine-tuned-gpt2')
model = GPT2LMHeadModel.from_pretrained('/kaggle/input/notebook9c426c2851/fine-tuned-gpt2')

# Set eos_token as pad_token
tokenizer.pad_token = tokenizer.eos_token

# Tokenize the dataset
inputs = tokenizer(recipes, return_tensors='pt', max_length=512, truncation=True, padding='max_length')
dataset = torch.utils.data.TensorDataset(inputs["input_ids"], inputs["attention_mask"])

# %%
from torch.utils.data import Dataset
from transformers import GPT2Tokenizer, GPT2LMHeadModel, Trainer, TrainingArguments, DataCollatorForLanguageModeling

class RecipeDataset(Dataset):
    def __init__(self, encodings):
        self.encodings = encodings

    def __getitem__(self, idx):
        item = {key: val[idx].clone().detach() for key, val in self.encodings.items()}
        return item

    def __len__(self):
        return len(self.encodings['input_ids'])

# Create the dataset
dataset = RecipeDataset(inputs)

# %%
# Define data collator
data_collator = DataCollatorForLanguageModeling(tokenizer=tokenizer, mlm=False)

import wandb

wandb.login(key='c65824cada15b84e31e7e9f35db6fe50eecfd857')

# Define training arguments
training_args = TrainingArguments(
    output_dir='./results',
    warmup_steps=1000,
    learning_rate=5e-5,
    num_train_epochs=5,
    weight_decay=0.001,
    per_device_train_batch_size=4,  # Adjust based on your GPU's capacity
    save_steps=1000,
    save_total_limit=2,
    prediction_loss_only=True,
    fp16=True
)

# Use the Trainer class to fine-tune the model
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=dataset,
    data_collator=data_collator
)

# Train the model
trainer.train()

# Save the fine-tuned model
model.save_pretrained("fine-tuned-gpt2")
tokenizer.save_pretrained("fine-tuned-gpt2")
# Out:
# wandb: Using wandb-core as the SDK backend. Please refer to https://wandb.me/wandb-core for more information.
# wandb: W&B API key is configured. Use `wandb login --relogin` to force relogin
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# /opt/conda/lib/python3.10/site-packages/accelerate/accelerator.py:494: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   self.scaler = torch.cuda.amp.GradScaler(**kwargs)
# wandb: WARNING The `run_name` is currently set to the same value as `TrainingArguments.output_dir`. If this was not intended, please specify a different run name by setting the `TrainingArguments.run_name` parameter.
# wandb: Currently logged in as: klmnopganesh (klmnopganesh-memorial-university-of-newfoundland). Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.18.1
# wandb: Run data is saved locally in /kaggle/working/wandb/run-20240925_000326-dkjtolri
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run ./results
# wandb: ⭐️ View project at https://wandb.ai/klmnopganesh-memorial-university-of-newfoundland/huggingface
# wandb: 🚀 View run at https://wandb.ai/klmnopganesh-memorial-university-of-newfoundland/huggingface/runs/dkjtolri
#     <div>
#
#       <progress value='72390' max='72390' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [72390/72390 7:06:13, Epoch 5/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>500</td>
#       <td>1.785400</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>1.763800</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>1.767100</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>1.767800</td>
#     </tr>
#     <tr>
#       <td>2500</td>
#       <td>1.787800</td>
#     </tr>
#     <tr>
#       <td>3000</td>
#       <td>1.748800</td>
#     </tr>
#     <tr>
#       <td>3500</td>
#       <td>1.752700</td>
#     </tr>
#     <tr>
#       <td>4000</td>
#       <td>1.757100</td>
#     </tr>
#     <tr>
#       <td>4500</td>
#       <td>1.747200</td>
#     </tr>
#     <tr>
#       <td>5000</td>
#       <td>1.731100</td>
#     </tr>
#     <tr>
#       <td>5500</td>
#       <td>1.726600</td>
#     </tr>
#     <tr>
#       <td>6000</td>
#       <td>1.748200</td>
#     </tr>
#     <tr>
#       <td>6500</td>
#       <td>1.735200</td>
#     </tr>
#     <tr>
#       <td>7000</td>
#       <td>1.710200</td>
#     </tr>
#     <tr>
#       <td>7500</td>
#       <td>1.715100</td>
#     </tr>
#     <tr>
#       <td>8000</td>
#       <td>1.713800</td>
#     </tr>
#     <tr>
#       <td>8500</td>
#       <td>1.702500</td>
#     </tr>
#     <tr>
#       <td>9000</td>
#       <td>1.697800</td>
#     </tr>
#     <tr>
#       <td>9500</td>
#       <td>1.697800</td>
#     </tr>
#     <tr>
#       <td>10000</td>
#       <td>1.701200</td>
#     </tr>
#     <tr>
#       <td>10500</td>
#       <td>1.702700</td>
#     </tr>
#     <tr>
#       <td>11000</td>
#       <td>1.678100</td>
#     </tr>
#     <tr>
#       <td>11500</td>
#       <td>1.715200</td>
#     </tr>
#     <tr>
#       <td>12000</td>
#       <td>1.711600</td>
#     </tr>
#     <tr>
#       <td>12500</td>
#       <td>1.689200</td>
#     </tr>
#     <tr>
#       <td>13000</td>
#       <td>1.698700</td>
#     </tr>
#     <tr>
#       <td>13500</td>
#       <td>1.693800</td>
#     </tr>
#     <tr>
#       <td>14000</td>
#       <td>1.680400</td>
#     </tr>
#     <tr>
#       <td>14500</td>
#       <td>1.692500</td>
#     </tr>
#     <tr>
#       <td>15000</td>
#       <td>1.614900</td>
#     </tr>
#     <tr>
#       <td>15500</td>
#       <td>1.647800</td>
#     </tr>
#     <tr>
#       <td>16000</td>
#       <td>1.629300</td>
#     </tr>
#     <tr>
#       <td>16500</td>
#       <td>1.612400</td>
#     </tr>
#     <tr>
#       <td>17000</td>
#       <td>1.632900</td>
#     </tr>
#     <tr>
#       <td>17500</td>
#       <td>1.638400</td>
#     </tr>
#     <tr>
#       <td>18000</td>
#       <td>1.626200</td>
#     </tr>
#     <tr>
#       <td>18500</td>
#       <td>1.640200</td>
#     </tr>
#     <tr>
#       <td>19000</td>
#       <td>1.633500</td>
#     </tr>
#     <tr>
#       <td>19500</td>
#       <td>1.637000</td>
#     </tr>
#     <tr>
#       <td>20000</td>
#       <td>1.632400</td>
#     </tr>
#     <tr>
#       <td>20500</td>
#       <td>1.627900</td>
#     </tr>
#     <tr>
#       <td>21000</td>
#       <td>1.631000</td>
#     </tr>
#     <tr>
#       <td>21500</td>
#       <td>1.646200</td>
#     </tr>
#     <tr>
#       <td>22000</td>
#       <td>1.623000</td>
#     </tr>
#     <tr>
#       <td>22500</td>
#       <td>1.628600</td>
#     </tr>
#     <tr>
#       <td>23000</td>
#       <td>1.638400</td>
#     </tr>
#     <tr>
#       <td>23500</td>
#       <td>1.640100</td>
#     </tr>
#     <tr>
#       <td>24000</td>
#       <td>1.636000</td>
#     </tr>
#     <tr>
#       <td>24500</td>
#       <td>1.598900</td>
#     </tr>
#     <tr>
#       <td>25000</td>
#       <td>1.627400</td>
#     </tr>
#     <tr>
#       <td>25500</td>
#       <td>1.624300</td>
#     </tr>
#     <tr>
#       <td>26000</td>
#       <td>1.627300</td>
#     </tr>
#     <tr>
#       <td>26500</td>
#       <td>1.614300</td>
#     </tr>
#     <tr>
#       <td>27000</td>
#       <td>1.599200</td>
#     </tr>
#     <tr>
#       <td>27500</td>
#       <td>1.618000</td>
#     </tr>
#     <tr>
#       <td>28000</td>
#       <td>1.597700</td>
#     </tr>
#     <tr>
#       <td>28500</td>
#       <td>1.623300</td>
#     </tr>
#     <tr>
#       <td>29000</td>
#       <td>1.624000</td>
#     </tr>
#     <tr>
#       <td>29500</td>
#       <td>1.563900</td>
#     </tr>
#     <tr>
#       <td>30000</td>
#       <td>1.569700</td>
#     </tr>
#     <tr>
#       <td>30500</td>
#       <td>1.565500</td>
#     </tr>
#     <tr>
#       <td>31000</td>
#       <td>1.572700</td>
#     </tr>
#     <tr>
#       <td>31500</td>
#       <td>1.573300</td>
#     </tr>
#     <tr>
#       <td>32000</td>
#       <td>1.577300</td>
#     </tr>
#     <tr>
#       <td>32500</td>
#       <td>1.577500</td>
#     </tr>
#     <tr>
#       <td>33000</td>
#       <td>1.564300</td>
#     </tr>
#     <tr>
#       <td>33500</td>
#       <td>1.557900</td>
#     </tr>
#     <tr>
#       <td>34000</td>
#       <td>1.569000</td>
#     </tr>
#     <tr>
#       <td>34500</td>
#       <td>1.572200</td>
#     </tr>
#     <tr>
#       <td>35000</td>
#       <td>1.572200</td>
#     </tr>
#     <tr>
#       <td>35500</td>
#       <td>1.577100</td>
#     </tr>
#     <tr>
#       <td>36000</td>
#       <td>1.575000</td>
#     </tr>
#     <tr>
#       <td>36500</td>
#       <td>1.583300</td>
#     </tr>
#     <tr>
#       <td>37000</td>
#       <td>1.562100</td>
#     </tr>
#     <tr>
#       <td>37500</td>
#       <td>1.572200</td>
#     </tr>
#     <tr>
#       <td>38000</td>
#       <td>1.549500</td>
#     </tr>
#     <tr>
#       <td>38500</td>
#       <td>1.566000</td>
#     </tr>
#     <tr>
#       <td>39000</td>
#       <td>1.571600</td>
#     </tr>
#     <tr>
#       <td>39500</td>
#       <td>1.564400</td>
#     </tr>
#     <tr>
#       <td>40000</td>
#       <td>1.549000</td>
#     </tr>
#     <tr>
#       <td>40500</td>
#       <td>1.571100</td>
#     </tr>
#     <tr>
#       <td>41000</td>
#       <td>1.564300</td>
#     </tr>
#     <tr>
#       <td>41500</td>
#       <td>1.569400</td>
#     </tr>
#     <tr>
#       <td>42000</td>
#       <td>1.556800</td>
#     </tr>
#     <tr>
#       <td>42500</td>
#       <td>1.571200</td>
#     </tr>
#     <tr>
#       <td>43000</td>
#       <td>1.564300</td>
#     </tr>
#     <tr>
#       <td>43500</td>
#       <td>1.578600</td>
#     </tr>
#     <tr>
#       <td>44000</td>
#       <td>1.519800</td>
#     </tr>
#     <tr>
#       <td>44500</td>
#       <td>1.536500</td>
#     </tr>
#     <tr>
#       <td>45000</td>
#       <td>1.525500</td>
#     </tr>
#     <tr>
#       <td>45500</td>
#       <td>1.520700</td>
#     </tr>
#     <tr>
#       <td>46000</td>
#       <td>1.533200</td>
#     </tr>
#     <tr>
#       <td>46500</td>
#       <td>1.527100</td>
#     </tr>
#     <tr>
#       <td>47000</td>
#       <td>1.512500</td>
#     </tr>
#     <tr>
#       <td>47500</td>
#       <td>1.523200</td>
#     </tr>
#     <tr>
#       <td>48000</td>
#       <td>1.521600</td>
#     </tr>
#     <tr>
#       <td>48500</td>
#       <td>1.532200</td>
#     </tr>
#     <tr>
#       <td>49000</td>
#       <td>1.550500</td>
#     </tr>
#     <tr>
#       <td>49500</td>
#       <td>1.523500</td>
#     </tr>
#     <tr>
#       <td>50000</td>
#       <td>1.545100</td>
#     </tr>
#     <tr>
#       <td>50500</td>
#       <td>1.526100</td>
#     </tr>
#     <tr>
#       <td>51000</td>
#       <td>1.510900</td>
#     </tr>
#     <tr>
#       <td>51500</td>
#       <td>1.520300</td>
#     </tr>
#     <tr>
#       <td>52000</td>
#       <td>1.513300</td>
#     </tr>
#     <tr>
#       <td>52500</td>
#       <td>1.523500</td>
#     </tr>
#     <tr>
#       <td>53000</td>
#       <td>1.535700</td>
#     </tr>
#     <tr>
#       <td>53500</td>
#       <td>1.517000</td>
#     </tr>
#     <tr>
#       <td>54000</td>
#       <td>1.523200</td>
#     </tr>
#     <tr>
#       <td>54500</td>
#       <td>1.535400</td>
#     </tr>
#     <tr>
#       <td>55000</td>
#       <td>1.523700</td>
#     </tr>
#     <tr>
#       <td>55500</td>
#       <td>1.542200</td>
#     </tr>
#     <tr>
#       <td>56000</td>
#       <td>1.525100</td>
#     </tr>
#     <tr>
#       <td>56500</td>
#       <td>1.544500</td>
#     </tr>
#     <tr>
#       <td>57000</td>
#       <td>1.534200</td>
#     </tr>
#     <tr>
#       <td>57500</td>
#       <td>1.532300</td>
#     </tr>
#     <tr>
#       <td>58000</td>
#       <td>1.523900</td>
#     </tr>
#     <tr>
#       <td>58500</td>
#       <td>1.489100</td>
#     </tr>
#     <tr>
#       <td>59000</td>
#       <td>1.495000</td>
#     </tr>
#     <tr>
#       <td>59500</td>
#       <td>1.502000</td>
#     </tr>
#     <tr>
#       <td>60000</td>
#       <td>1.502900</td>
#     </t
# ('fine-tuned-gpt2/tokenizer_config.json',
#  'fine-tuned-gpt2/special_tokens_map.json',
#  'fine-tuned-gpt2/vocab.json',
#  'fine-tuned-gpt2/merges.txt',
#  'fine-tuned-gpt2/added_tokens.json')

# %%
import os

# Define the path
path = '/kaggle/working/'

# Walk through the directory and print files and subdirectories
for root, dirs, files in os.walk(path):
    print(f"Root directory: {root}")
    for directory in dirs:
        print(f"Subdirectory: {directory}")
    for file in files:
        print(f"File: {file}")
# Out:
# Root directory: /kaggle/working/
# Subdirectory: fine-tuned-gpt2
# Subdirectory: wandb
# Subdirectory: results
# File: __notebook__.ipynb
# Root directory: /kaggle/working/fine-tuned-gpt2
# File: model.safetensors
# File: tokenizer_config.json
# File: generation_config.json
# File: vocab.json
# File: special_tokens_map.json
# File: config.json
# File: merges.txt
# Root directory: /kaggle/working/wandb
# Subdirectory: run-20240925_000326-dkjtolri
# Subdirectory: latest-run
# File: debug.log
# File: debug-internal.log
# Root directory: /kaggle/working/wandb/run-20240925_000326-dkjtolri
# Subdirectory: tmp
# Subdirectory: logs
# Subdirectory: files
# File: run-dkjtolri.wandb
# Root directory: /kaggle/working/wandb/run-20240925_000326-dkjtolri/tmp
# Subdirectory: code
# Root directory: /kaggle/working/wandb/run-20240925_000326-dkjtolri/tmp/code
# Root directory: /kaggle/working/wandb/run-20240925_000326-dkjtolri/logs
# File: debug.log
# File: debug-core.log
# File: debug-internal.log
# Root directory: /kaggle/working/wandb/run-20240925_000326-dkjtolri/files
# File: wandb-metadata.json
# File: output.log
# File: requirements.txt
# Root directory: /kaggle/working/results
# Subdirectory: checkpoint-72000
# Subdirectory: runs
# Subdirectory: checkpoint-72390
# Root directory: /kaggle/working/results/checkpoint-72000
# File: rng_state.pth
# File: scheduler.pt
# File: model.safetensors
# File: training_args.bin
# File: generation_config.json
# File: optimizer.pt
# File: trainer_state.json
# File: config.json
# Root directory: /kaggle/working/results/runs
# Subdirectory: Sep25_00-03-20_0b6941dd7482
# Root directory: /kaggle/working/results/runs/Sep25_00-03-20_0b6941dd7482
# File: events.out.tfevents.1727222606.0b6941dd7482.24.0
# Root directory: /kaggle/working/results/checkpoint-72390
# File: rng_state.pth
# File: scheduler.pt
# File: model.safetensors
# File: training_args.bin
# File: generation_config.json
# File: optimizer.pt
# File: trainer_state.json
# File: config.json
