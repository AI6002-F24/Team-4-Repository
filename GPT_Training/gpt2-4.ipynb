# %%
## This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/gpt2-3/__results__.html
# /kaggle/input/gpt2-3/__notebook__.ipynb
# /kaggle/input/gpt2-3/__output__.json
# /kaggle/input/gpt2-3/custom.css
# /kaggle/input/gpt2-3/fine-tuned-gpt2/config.json
# /kaggle/input/gpt2-3/fine-tuned-gpt2/merges.txt
# /kaggle/input/gpt2-3/fine-tuned-gpt2/vocab.json
# /kaggle/input/gpt2-3/fine-tuned-gpt2/tokenizer_config.json
# /kaggle/input/gpt2-3/fine-tuned-gpt2/model.safetensors
# /kaggle/input/gpt2-3/fine-tuned-gpt2/special_tokens_map.json
# /kaggle/input/gpt2-3/fine-tuned-gpt2/generation_config.json
# /kaggle/input/gpt2-3/results/runs/Sep25_15-24-05_78ebbb3607d6/events.out.tfevents.1727277850.78ebbb3607d6.23.0
# /kaggle/input/gpt2-3/results/checkpoint-72000/config.json
# /kaggle/input/gpt2-3/results/checkpoint-72000/trainer_state.json
# /kaggle/input/gpt2-3/results/checkpoint-72000/training_args.bin
# /kaggle/input/gpt2-3/results/checkpoint-72000/scheduler.pt
# /kaggle/input/gpt2-3/results/checkpoint-72000/model.safetensors
# /kaggle/input/gpt2-3/results/checkpoint-72000/optimizer.pt
# /kaggle/input/gpt2-3/results/checkpoint-72000/rng_state.pth
# /kaggle/input/gpt2-3/results/checkpoint-72000/generation_config.json
# /kaggle/input/gpt2-3/results/checkpoint-72390/config.json
# /kaggle/input/gpt2-3/results/checkpoint-72390/trainer_state.json
# /kaggle/input/gpt2-3/results/checkpoint-72390/training_args.bin
# /kaggle/input/gpt2-3/results/checkpoint-72390/scheduler.pt
# /kaggle/input/gpt2-3/results/checkpoint-72390/model.safetensors
# /kaggle/input/gpt2-3/results/checkpoint-72390/optimizer.pt
# /kaggle/input/gpt2-3/results/checkpoint-72390/rng_state.pth
# /kaggle/input/gpt2-3/results/checkpoint-72390/generation_config.json
# /kaggle/input/gpt2-3/wandb/run-20240925_152410-mr2bsfna/run-mr2bsfna.wandb
# /kaggle/input/gpt2-3/wandb/run-20240925_152410-mr2bsfna/logs/debug.log
# /kaggle/input/gpt2-3/wandb/run-20240925_152410-mr2bsfna/logs/debug-internal.log
# /kaggle/input/gpt2-3/wandb/run-20240925_152410-mr2bsfna/files/wandb-summary.json
# /kaggle/input/gpt2-3/wandb/run-20240925_152410-mr2bsfna/files/config.yaml
# /kaggle/input/gpt2-3/wandb/run-20240925_152410-mr2bsfna/files/output.log
# /kaggle/input/gpt2-3/wandb/run-20240925_152410-mr2bsfna/files/requirements.txt
# /kaggle/input/gpt2-3/wandb/run-20240925_152410-mr2bsfna/files/wandb-metadata.json
# /kaggle/input/food-com-recipes-and-user-interactions/RAW_interactions.csv
# /kaggle/input/food-com-recipes-and-user-interactions/ingr_map.pkl
# /kaggle/input/food-com-recipes-and-user-interactions/PP_recipes.csv
# /kaggle/input/food-com-recipes-and-user-interactions/RAW_recipes.csv
# /kaggle/input/food-com-recipes-and-user-interactions/interactions_train.csv
# /kaggle/input/food-com-recipes-and-user-interactions/interactions_test.csv
# /kaggle/input/food-com-recipes-and-user-interactions/PP_users.csv
# /kaggle/input/food-com-recipes-and-user-interactions/interactions_validation.csv

# %%
# Read data
import pickle

ingr_map = pd.read_pickle("/kaggle/input/food-com-recipes-and-user-interactions/ingr_map.pkl")
input_path = "/kaggle/input/food-com-recipes-and-user-interactions/"
df_recipes = pd.read_csv(input_path + "RAW_recipes.csv")

print(df_recipes.shape)
# Out:
# (231637, 12)

# %%
df_recipes.head()
# Out:
#                                          name      id  minutes  \
# 0  arriba   baked winter squash mexican style  137739       55
# 1            a bit different  breakfast pizza   31490       30
# 2                   all in the kitchen  chili  112140      130
# 3                          alouette  potatoes   59389       45
# 4          amish  tomato ketchup  for canning   44061      190
#
#    contributor_id   submitted  \
# 0           47892  2005-09-16
# 1           26278  2002-06-17
# 2          196586  2005-02-25
# 3           68585  2003-04-14
# 4           41706  2002-10-25
#
#                                                 tags  \
# 0  ['60-minutes-or-less', 'time-to-make', 'course...
# 1  ['30-minutes-or-less', 'time-to-make', 'course...
# 2  ['time-to-make', 'course', 'preparation', 'mai...
# 3  ['60-minutes-or-less', 'time-to-make', 'course...
# 4  ['weeknight', 'time-to-make', 'course', 'main-...
#
#                                     nutrition  n_steps  \
# 0       [51.5, 0.0, 13.0, 0.0, 2.0, 0.0, 4.0]       11
# 1   [173.4, 18.0, 0.0, 17.0, 22.0, 35.0, 1.0]        9
# 2  [269.8, 22.0, 32.0, 48.0, 39.0, 27.0, 5.0]        6
# 3   [368.1, 17.0, 10.0, 2.0, 14.0, 8.0, 20.0]       11
# 4   [352.9, 1.0, 337.0, 23.0, 3.0, 0.0, 28.0]        5
#
#                                                steps  \
# 0  ['make a choice and proceed with recipe', 'dep...
# 1  ['preheat oven to 425 degrees f', 'press dough...
# 2  ['brown ground beef in large pot', 'add choppe...
# 3  ['place potatoes in a large pot of lightly sal...
# 4  ['mix all ingredients& boil for 2 1 / 2 hours ...
#
#                                          description  \
# 0  autumn is my favorite time of year to cook! th...
# 1  this recipe calls for the crust to be prebaked...
# 2  this modified version of 'mom's' chili was a h...
# 3  this is a super easy, great tasting, make ahea...
# 4  my dh's amish mother raised him on this recipe...
#
#                                          ingredients  n_ingredients
# 0  ['winter squash', 'mexican seasoning', 'mixed ...              7
# 1  ['prepared pizza crust', 'sausage patty', 'egg...              6
# 2  ['ground beef', 'yellow onions', 'diced tomato...             13
# 3  ['spreadable cheese with garlic and herbs', 'n...             11
# 4  ['tomato juice', 'apple cider vinegar', 'sugar...              8

# %%
import ast

replacement_dict = pd.Series(ingr_map['replaced'].values, index=ingr_map['raw_ingr']).to_dict()

# Function to convert and replace ingredients
def convert_and_replace(ingredient_str, replacement_dict):
    try:
        # Convert string representation of list to actual list
        ingredient_list = ast.literal_eval(ingredient_str)
        # Replace ingredients
        replaced_list = [replacement_dict.get(ingredient, ingredient) for ingredient in ingredient_list]
        return replaced_list
    except (ValueError, SyntaxError):
        # Handle cases where conversion fails
        return []

# Apply replacement to the ingredients column
df_recipes['ingredients'] = df_recipes['ingredients'].apply(lambda x: convert_and_replace(x, replacement_dict))

# %%
print(df_recipes.shape)
df_recipes.head()
# Out:
# (231637, 12)
#                                          name      id  minutes  \
# 0  arriba   baked winter squash mexican style  137739       55
# 1            a bit different  breakfast pizza   31490       30
# 2                   all in the kitchen  chili  112140      130
# 3                          alouette  potatoes   59389       45
# 4          amish  tomato ketchup  for canning   44061      190
#
#    contributor_id   submitted  \
# 0           47892  2005-09-16
# 1           26278  2002-06-17
# 2          196586  2005-02-25
# 3           68585  2003-04-14
# 4           41706  2002-10-25
#
#                                                 tags  \
# 0  ['60-minutes-or-less', 'time-to-make', 'course...
# 1  ['30-minutes-or-less', 'time-to-make', 'course...
# 2  ['time-to-make', 'course', 'preparation', 'mai...
# 3  ['60-minutes-or-less', 'time-to-make', 'course...
# 4  ['weeknight', 'time-to-make', 'course', 'main-...
#
#                                     nutrition  n_steps  \
# 0       [51.5, 0.0, 13.0, 0.0, 2.0, 0.0, 4.0]       11
# 1   [173.4, 18.0, 0.0, 17.0, 22.0, 35.0, 1.0]        9
# 2  [269.8, 22.0, 32.0, 48.0, 39.0, 27.0, 5.0]        6
# 3   [368.1, 17.0, 10.0, 2.0, 14.0, 8.0, 20.0]       11
# 4   [352.9, 1.0, 337.0, 23.0, 3.0, 0.0, 28.0]        5
#
#                                                steps  \
# 0  ['make a choice and proceed with recipe', 'dep...
# 1  ['preheat oven to 425 degrees f', 'press dough...
# 2  ['brown ground beef in large pot', 'add choppe...
# 3  ['place potatoes in a large pot of lightly sal...
# 4  ['mix all ingredients& boil for 2 1 / 2 hours ...
#
#                                          description  \
# 0  autumn is my favorite time of year to cook! th...
# 1  this recipe calls for the crust to be prebaked...
# 2  this modified version of 'mom's' chili was a h...
# 3  this is a super easy, great tasting, make ahea...
# 4  my dh's amish mother raised him on this recipe...
#
#                                          ingredients  n_ingredients
# 0  [winter squash, mexican seasoning, mixed spice...              7
# 1  [pizza crust, sausage, egg, milk, salt and pep...              6
# 2  [ground beef, yellow onion, diced tomato, toma...             13
# 3  [cheese, new potato, shallot, parsley, tarrago...             11
# 4  [tomato juice, apple cider vinegar, sugar, sal...              8

# %%
df_recipes = df_recipes.iloc[115818:173727]
print(df_recipes.shape)
# Out:
# (57909, 12)

# %%
# Combine the relevant columns into a new dataframe
df_simplified = df_recipes[['minutes', 'ingredients', 'steps']].copy()

# Format the ingredients as a comma-separated string for better readability
df_simplified['ingredients'] = df_simplified['ingredients'].apply(lambda x: ', '.join(x))

# Combine all columns into a single text block format for the transformer model
def format_recipe_simple(row):
    return (
        f"Cooking Time: {row['minutes']} minutes "
        f"Ingredients: {row['ingredients']} "
        f"Steps: {row['steps']} "
    )

df_simplified['formatted_recipe'] = df_simplified.apply(format_recipe_simple, axis=1)

df_simplified.head()
# Out:
#         minutes                                        ingredients  \
# 115818        5  milk, instant breakfast drink mix, banana, cho...
# 115819        5    strawberry, honey, vanilla, milk, egg, ice cube
# 115820       35  baked bean, ground beef, onion, ketchup, brown...
# 115821      100  dry lentil, water, olive oil, balsamic vinegar...
# 115822      490  flank steak, soy sauce, olive oil, lemon, juic...
#
#                                                     steps  \
# 115818  ['slice banana and put all ingredients into th...
# 115819  ['hull strawberries and slice in half', 'put a...
# 115820  ['preheat oven to 350', 'remove 6 slices of ba...
# 115821  ['using a food processor , finely mince the ap...
# 115822  ['lightly score meat on top and bottom', 'mix ...
#
#                                          formatted_recipe
# 115818  Cooking Time: 5 minutes Ingredients: milk, ins...
# 115819  Cooking Time: 5 minutes Ingredients: strawberr...
# 115820  Cooking Time: 35 minutes Ingredients: baked be...
# 115821  Cooking Time: 100 minutes Ingredients: dry len...
# 115822  Cooking Time: 490 minutes Ingredients: flank s...

# %%
recipes = df_simplified['formatted_recipe'].tolist()

from transformers import GPT2Tokenizer, GPT2LMHeadModel, Trainer, TrainingArguments
import torch

# Load the pre-trained GPT-2 model and tokenizer
# model_name = "gpt2"
tokenizer = GPT2Tokenizer.from_pretrained('/kaggle/input/gpt2-3/fine-tuned-gpt2')
model = GPT2LMHeadModel.from_pretrained('/kaggle/input/gpt2-3/fine-tuned-gpt2')

# Set eos_token as pad_token
tokenizer.pad_token = tokenizer.eos_token

# Tokenize the dataset
inputs = tokenizer(recipes, return_tensors='pt', max_length=512, truncation=True, padding='max_length')
dataset = torch.utils.data.TensorDataset(inputs["input_ids"], inputs["attention_mask"])

# %%
from torch.utils.data import Dataset
from transformers import GPT2Tokenizer, GPT2LMHeadModel, Trainer, TrainingArguments, DataCollatorForLanguageModeling

class RecipeDataset(Dataset):
    def __init__(self, encodings):
        self.encodings = encodings

    def __getitem__(self, idx):
        item = {key: val[idx].clone().detach() for key, val in self.encodings.items()}
        return item

    def __len__(self):
        return len(self.encodings['input_ids'])

# Create the dataset
dataset = RecipeDataset(inputs)

# %%
# Define data collator
data_collator = DataCollatorForLanguageModeling(tokenizer=tokenizer, mlm=False)

import wandb

wandb.login(key='c65824cada15b84e31e7e9f35db6fe50eecfd857')

# Define training arguments
training_args = TrainingArguments(
    output_dir='./results',
    warmup_steps=1000,
    learning_rate=5e-5,
    num_train_epochs=5,
    weight_decay=0.001,
    per_device_train_batch_size=4,  # Adjust based on your GPU's capacity
    save_steps=1000,
    save_total_limit=2,
    prediction_loss_only=True,
    fp16=True
)

# Use the Trainer class to fine-tune the model
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=dataset,
    data_collator=data_collator
)

# Train the model
trainer.train()

# Save the fine-tuned model
model.save_pretrained("fine-tuned-gpt2")
tokenizer.save_pretrained("fine-tuned-gpt2")
# Out:
# wandb: Using wandb-core as the SDK backend. Please refer to https://wandb.me/wandb-core for more information.
# wandb: W&B API key is configured. Use `wandb login --relogin` to force relogin
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# /opt/conda/lib/python3.10/site-packages/accelerate/accelerator.py:494: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   self.scaler = torch.cuda.amp.GradScaler(**kwargs)
# wandb: WARNING The `run_name` is currently set to the same value as `TrainingArguments.output_dir`. If this was not intended, please specify a different run name by setting the `TrainingArguments.run_name` parameter.
# wandb: Currently logged in as: klmnopganesh (klmnopganesh-memorial-university-of-newfoundland). Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.18.3
# wandb: Run data is saved locally in /kaggle/working/wandb/run-20241017_225016-3m2szcui
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run ./results
# wandb: ⭐️ View project at https://wandb.ai/klmnopganesh-memorial-university-of-newfoundland/huggingface
# wandb: 🚀 View run at https://wandb.ai/klmnopganesh-memorial-university-of-newfoundland/huggingface/runs/3m2szcui
#     <div>
#
#       <progress value='72390' max='72390' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [72390/72390 7:06:15, Epoch 5/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>500</td>
#       <td>1.617900</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>1.599700</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>1.622000</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>1.623800</td>
#     </tr>
#     <tr>
#       <td>2500</td>
#       <td>1.618800</td>
#     </tr>
#     <tr>
#       <td>3000</td>
#       <td>1.615300</td>
#     </tr>
#     <tr>
#       <td>3500</td>
#       <td>1.626500</td>
#     </tr>
#     <tr>
#       <td>4000</td>
#       <td>1.618300</td>
#     </tr>
#     <tr>
#       <td>4500</td>
#       <td>1.622600</td>
#     </tr>
#     <tr>
#       <td>5000</td>
#       <td>1.614900</td>
#     </tr>
#     <tr>
#       <td>5500</td>
#       <td>1.630500</td>
#     </tr>
#     <tr>
#       <td>6000</td>
#       <td>1.619700</td>
#     </tr>
#     <tr>
#       <td>6500</td>
#       <td>1.639400</td>
#     </tr>
#     <tr>
#       <td>7000</td>
#       <td>1.616400</td>
#     </tr>
#     <tr>
#       <td>7500</td>
#       <td>1.604000</td>
#     </tr>
#     <tr>
#       <td>8000</td>
#       <td>1.617100</td>
#     </tr>
#     <tr>
#       <td>8500</td>
#       <td>1.601300</td>
#     </tr>
#     <tr>
#       <td>9000</td>
#       <td>1.612700</td>
#     </tr>
#     <tr>
#       <td>9500</td>
#       <td>1.611000</td>
#     </tr>
#     <tr>
#       <td>10000</td>
#       <td>1.608000</td>
#     </tr>
#     <tr>
#       <td>10500</td>
#       <td>1.626600</td>
#     </tr>
#     <tr>
#       <td>11000</td>
#       <td>1.590200</td>
#     </tr>
#     <tr>
#       <td>11500</td>
#       <td>1.603000</td>
#     </tr>
#     <tr>
#       <td>12000</td>
#       <td>1.585000</td>
#     </tr>
#     <tr>
#       <td>12500</td>
#       <td>1.634900</td>
#     </tr>
#     <tr>
#       <td>13000</td>
#       <td>1.614700</td>
#     </tr>
#     <tr>
#       <td>13500</td>
#       <td>1.615800</td>
#     </tr>
#     <tr>
#       <td>14000</td>
#       <td>1.616500</td>
#     </tr>
#     <tr>
#       <td>14500</td>
#       <td>1.589400</td>
#     </tr>
#     <tr>
#       <td>15000</td>
#       <td>1.564000</td>
#     </tr>
#     <tr>
#       <td>15500</td>
#       <td>1.558300</td>
#     </tr>
#     <tr>
#       <td>16000</td>
#       <td>1.549700</td>
#     </tr>
#     <tr>
#       <td>16500</td>
#       <td>1.529200</td>
#     </tr>
#     <tr>
#       <td>17000</td>
#       <td>1.540200</td>
#     </tr>
#     <tr>
#       <td>17500</td>
#       <td>1.551200</td>
#     </tr>
#     <tr>
#       <td>18000</td>
#       <td>1.526600</td>
#     </tr>
#     <tr>
#       <td>18500</td>
#       <td>1.558400</td>
#     </tr>
#     <tr>
#       <td>19000</td>
#       <td>1.558500</td>
#     </tr>
#     <tr>
#       <td>19500</td>
#       <td>1.564000</td>
#     </tr>
#     <tr>
#       <td>20000</td>
#       <td>1.549000</td>
#     </tr>
#     <tr>
#       <td>20500</td>
#       <td>1.545200</td>
#     </tr>
#     <tr>
#       <td>21000</td>
#       <td>1.551700</td>
#     </tr>
#     <tr>
#       <td>21500</td>
#       <td>1.550900</td>
#     </tr>
#     <tr>
#       <td>22000</td>
#       <td>1.537100</td>
#     </tr>
#     <tr>
#       <td>22500</td>
#       <td>1.560000</td>
#     </tr>
#     <tr>
#       <td>23000</td>
#       <td>1.551900</td>
#     </tr>
#     <tr>
#       <td>23500</td>
#       <td>1.548400</td>
#     </tr>
#     <tr>
#       <td>24000</td>
#       <td>1.545800</td>
#     </tr>
#     <tr>
#       <td>24500</td>
#       <td>1.557900</td>
#     </tr>
#     <tr>
#       <td>25000</td>
#       <td>1.571400</td>
#     </tr>
#     <tr>
#       <td>25500</td>
#       <td>1.549500</td>
#     </tr>
#     <tr>
#       <td>26000</td>
#       <td>1.544300</td>
#     </tr>
#     <tr>
#       <td>26500</td>
#       <td>1.556300</td>
#     </tr>
#     <tr>
#       <td>27000</td>
#       <td>1.544400</td>
#     </tr>
#     <tr>
#       <td>27500</td>
#       <td>1.546000</td>
#     </tr>
#     <tr>
#       <td>28000</td>
#       <td>1.547900</td>
#     </tr>
#     <tr>
#       <td>28500</td>
#       <td>1.540800</td>
#     </tr>
#     <tr>
#       <td>29000</td>
#       <td>1.546500</td>
#     </tr>
#     <tr>
#       <td>29500</td>
#       <td>1.496500</td>
#     </tr>
#     <tr>
#       <td>30000</td>
#       <td>1.504200</td>
#     </tr>
#     <tr>
#       <td>30500</td>
#       <td>1.501400</td>
#     </tr>
#     <tr>
#       <td>31000</td>
#       <td>1.500900</td>
#     </tr>
#     <tr>
#       <td>31500</td>
#       <td>1.496100</td>
#     </tr>
#     <tr>
#       <td>32000</td>
#       <td>1.493800</td>
#     </tr>
#     <tr>
#       <td>32500</td>
#       <td>1.475400</td>
#     </tr>
#     <tr>
#       <td>33000</td>
#       <td>1.509100</td>
#     </tr>
#     <tr>
#       <td>33500</td>
#       <td>1.506500</td>
#     </tr>
#     <tr>
#       <td>34000</td>
#       <td>1.489200</td>
#     </tr>
#     <tr>
#       <td>34500</td>
#       <td>1.511900</td>
#     </tr>
#     <tr>
#       <td>35000</td>
#       <td>1.505600</td>
#     </tr>
#     <tr>
#       <td>35500</td>
#       <td>1.523200</td>
#     </tr>
#     <tr>
#       <td>36000</td>
#       <td>1.497100</td>
#     </tr>
#     <tr>
#       <td>36500</td>
#       <td>1.521000</td>
#     </tr>
#     <tr>
#       <td>37000</td>
#       <td>1.487600</td>
#     </tr>
#     <tr>
#       <td>37500</td>
#       <td>1.514600</td>
#     </tr>
#     <tr>
#       <td>38000</td>
#       <td>1.495300</td>
#     </tr>
#     <tr>
#       <td>38500</td>
#       <td>1.489400</td>
#     </tr>
#     <tr>
#       <td>39000</td>
#       <td>1.512400</td>
#     </tr>
#     <tr>
#       <td>39500</td>
#       <td>1.492700</td>
#     </tr>
#     <tr>
#       <td>40000</td>
#       <td>1.495000</td>
#     </tr>
#     <tr>
#       <td>40500</td>
#       <td>1.500000</td>
#     </tr>
#     <tr>
#       <td>41000</td>
#       <td>1.507800</td>
#     </tr>
#     <tr>
#       <td>41500</td>
#       <td>1.504300</td>
#     </tr>
#     <tr>
#       <td>42000</td>
#       <td>1.506600</td>
#     </tr>
#     <tr>
#       <td>42500</td>
#       <td>1.494400</td>
#     </tr>
#     <tr>
#       <td>43000</td>
#       <td>1.502100</td>
#     </tr>
#     <tr>
#       <td>43500</td>
#       <td>1.501800</td>
#     </tr>
#     <tr>
#       <td>44000</td>
#       <td>1.447800</td>
#     </tr>
#     <tr>
#       <td>44500</td>
#       <td>1.485000</td>
#     </tr>
#     <tr>
#       <td>45000</td>
#       <td>1.464000</td>
#     </tr>
#     <tr>
#       <td>45500</td>
#       <td>1.459700</td>
#     </tr>
#     <tr>
#       <td>46000</td>
#       <td>1.448900</td>
#     </tr>
#     <tr>
#       <td>46500</td>
#       <td>1.469200</td>
#     </tr>
#     <tr>
#       <td>47000</td>
#       <td>1.460500</td>
#     </tr>
#     <tr>
#       <td>47500</td>
#       <td>1.459600</td>
#     </tr>
#     <tr>
#       <td>48000</td>
#       <td>1.468300</td>
#     </tr>
#     <tr>
#       <td>48500</td>
#       <td>1.461300</td>
#     </tr>
#     <tr>
#       <td>49000</td>
#       <td>1.464800</td>
#     </tr>
#     <tr>
#       <td>49500</td>
#       <td>1.463100</td>
#     </tr>
#     <tr>
#       <td>50000</td>
#       <td>1.475200</td>
#     </tr>
#     <tr>
#       <td>50500</td>
#       <td>1.463800</td>
#     </tr>
#     <tr>
#       <td>51000</td>
#       <td>1.475100</td>
#     </tr>
#     <tr>
#       <td>51500</td>
#       <td>1.461500</td>
#     </tr>
#     <tr>
#       <td>52000</td>
#       <td>1.469400</td>
#     </tr>
#     <tr>
#       <td>52500</td>
#       <td>1.445000</td>
#     </tr>
#     <tr>
#       <td>53000</td>
#       <td>1.476700</td>
#     </tr>
#     <tr>
#       <td>53500</td>
#       <td>1.473600</td>
#     </tr>
#     <tr>
#       <td>54000</td>
#       <td>1.453900</td>
#     </tr>
#     <tr>
#       <td>54500</td>
#       <td>1.458300</td>
#     </tr>
#     <tr>
#       <td>55000</td>
#       <td>1.472200</td>
#     </tr>
#     <tr>
#       <td>55500</td>
#       <td>1.468000</td>
#     </tr>
#     <tr>
#       <td>56000</td>
#       <td>1.459200</td>
#     </tr>
#     <tr>
#       <td>56500</td>
#       <td>1.479200</td>
#     </tr>
#     <tr>
#       <td>57000</td>
#       <td>1.476800</td>
#     </tr>
#     <tr>
#       <td>57500</td>
#       <td>1.464800</td>
#     </tr>
#     <tr>
#       <td>58000</td>
#       <td>1.471500</td>
#     </tr>
#     <tr>
#       <td>58500</td>
#       <td>1.445000</td>
#     </tr>
#     <tr>
#       <td>59000</td>
#       <td>1.432100</td>
#     </tr>
#     <tr>
#       <td>59500</td>
#       <td>1.438800</td>
#     </tr>
#     <tr>
#       <td>60000</td>
#       <td>1.426800</td>
#     </t
# ('fine-tuned-gpt2/tokenizer_config.json',
#  'fine-tuned-gpt2/special_tokens_map.json',
#  'fine-tuned-gpt2/vocab.json',
#  'fine-tuned-gpt2/merges.txt',
#  'fine-tuned-gpt2/added_tokens.json')

# %%
import os

# Define the path
path = '/kaggle/working/'

# Walk through the directory and print files and subdirectories
for root, dirs, files in os.walk(path):
    print(f"Root directory: {root}")
    for directory in dirs:
        print(f"Subdirectory: {directory}")
    for file in files:
        print(f"File: {file}")
# Out:
# Root directory: /kaggle/working/
# Subdirectory: fine-tuned-gpt2
# Subdirectory: results
# Subdirectory: wandb
# File: __notebook__.ipynb
# Root directory: /kaggle/working/fine-tuned-gpt2
# File: vocab.json
# File: generation_config.json
# File: special_tokens_map.json
# File: tokenizer_config.json
# File: merges.txt
# File: config.json
# File: model.safetensors
# Root directory: /kaggle/working/results
# Subdirectory: checkpoint-72000
# Subdirectory: checkpoint-72390
# Subdirectory: runs
# Root directory: /kaggle/working/results/checkpoint-72000
# File: training_args.bin
# File: rng_state.pth
# File: trainer_state.json
# File: generation_config.json
# File: optimizer.pt
# File: scheduler.pt
# File: config.json
# File: model.safetensors
# Root directory: /kaggle/working/results/checkpoint-72390
# File: training_args.bin
# File: rng_state.pth
# File: trainer_state.json
# File: generation_config.json
# File: optimizer.pt
# File: scheduler.pt
# File: config.json
# File: model.safetensors
# Root directory: /kaggle/working/results/runs
# Subdirectory: Oct17_22-50-11_c79602a86d4e
# Root directory: /kaggle/working/results/runs/Oct17_22-50-11_c79602a86d4e
# File: events.out.tfevents.1729205416.c79602a86d4e.23.0
# Root directory: /kaggle/working/wandb
# Subdirectory: run-20241017_225016-3m2szcui
# Subdirectory: latest-run
# File: debug-internal.log
# File: debug.log
# Root directory: /kaggle/working/wandb/run-20241017_225016-3m2szcui
# Subdirectory: files
# Subdirectory: tmp
# Subdirectory: logs
# File: run-3m2szcui.wandb
# Root directory: /kaggle/working/wandb/run-20241017_225016-3m2szcui/files
# File: requirements.txt
# File: wandb-metadata.json
# File: output.log
# Root directory: /kaggle/working/wandb/run-20241017_225016-3m2szcui/tmp
# Subdirectory: code
# Root directory: /kaggle/working/wandb/run-20241017_225016-3m2szcui/tmp/code
# Root directory: /kaggle/working/wandb/run-20241017_225016-3m2szcui/logs
# File: debug-internal.log
# File: debug-core.log
# File: debug.log
